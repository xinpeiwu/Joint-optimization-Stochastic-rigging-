# %% [markdown]
# ### Access the file stored in drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as T
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torch.utils.data as data
from torchvision.utils import make_grid
from torchvision import transforms
from collections import Counter
from PIL import Image
import torch.optim as optim
import matplotlib.pyplot as plt
import matplotlib.image as img
import numpy as np
import pandas as pd
import random
import os
# %matplotlib inline

# %%
# GPU
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
print('GPU State:', device)
# Out:
# GPU State: cpu

# %%
# Hyperparameter
NUM_EPOCHS = 20
BATCH_SIZE = 4
LR = 0.001

# %%
train_dir = os.path.join(os.getcwd(),"drive/MyDrive/HW3/train/images")
test_dir = os.path.join(os.getcwd(),"drive/MyDrive/HW3/test/test")
print(train_dir)
# Out:
# /content/drive/MyDrive/HW3/train/images

# %%
TRANSFORM_IMG = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize(100)
    ])

# %% [markdown]
# ### Load all the data

# %%
train_data = torchvision.datasets.ImageFolder(root=train_dir, transform=TRANSFORM_IMG)
train_data_loader = data.DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True,  num_workers=1)

# %% [markdown]
# ### Information of dataset

# %%
x = list(train_data.class_to_idx.values())
print(train_data.classes)
print(x)
print(train_data.imgs)
print(dict(Counter(train_data.targets)))
im = Image.open(train_data.imgs[0][0])
display(im)
print(im.mode)
# Out:
# ['crazing', 'inclusion', 'patches', 'pitted_surface', 'rolled-in_scale', 'scratches']
# [0, 1, 2, 3, 4, 5]
# [('/content/drive/MyDrive/HW3/train/images/crazing/crazing_1.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_10.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_100.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_101.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_102.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_103.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_104.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_105.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_106.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_107.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_108.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_109.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_11.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_110.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_111.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_112.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_113.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_114.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_115.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_116.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_117.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_118.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_119.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_12.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_120.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_121.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_122.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_123.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_124.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_125.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_126.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_127.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_128.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_129.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_13.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_130.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_131.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_132.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_133.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_134.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_135.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_136.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_137.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_138.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_139.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_14.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_140.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_141.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_142.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_143.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_144.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_145.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_146.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_147.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/crazing/crazing_148.jpg', 0), ('/content/drive/MyDrive/HW3/train/images/craz ...
# {0: 240, 1: 240, 2: 240, 3: 240, 4: 240, 5: 240}
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x7FF72C6B2890>
# RGB

# %%
def visualize_batch(batch, classes, dataset_type):
    # initialize a figure
    fig = plt.figure("{} batch".format(dataset_type),
        figsize=(10, 10))
    # loop over the batch size
    for i in range(0, BATCH_SIZE):
        # create a subplot
        ax = plt.subplot(2, 4, i + 1)
        # grab the image, convert it from channels first ordering to
        # channels last ordering, and scale the raw pixel intensities
        # to the range [0, 255]
        image = batch[0][i].cpu().numpy()
        image = image.transpose((1, 2, 0))
        image = (image * 255.0).astype("uint8")
        # grab the label id and get the label from the classes list
        idx = batch[1][i]
        label = classes[idx]
        # show the image along with the label
        plt.imshow(image)
        plt.title(label)
        plt.axis("off")
    # show the plot
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Plot different types of surface defect

# %%
trainBatch = next(iter(train_data_loader))
print("Visualizing some random training batch...")
visualize_batch(trainBatch, train_data.classes, "train")
# Out:
# Visualizing some random training batch...

# %% [markdown]
# ### Define the CNN architecture
# Tips:
# - try different size of out_channels/ conv layer/ kernel

# %%
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        # image shape is 3 * 100 * 100, where 3 is  color channel
        # 100 * 100 is the image size
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=18, kernel_size=5)    # output shape = 18 * 96 * 96
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2
# [18,    60] loss: 0.521
# [18,    80] loss: 0.592
# [18,   100] loss: 0.345
# [18,   120] loss: 0.676
# [18,   140] loss: 1.104
# [18,   160] loss: 0.530
# [18,   180] loss: 0.464
# [18,   200] loss: 0.475
# [18,   220] loss: 0.531
# [18,   240] loss: 0.469
# [18,   260] loss: 0.423
# [18,   280] loss: 0.286
# [18,   300] loss: 1.007
# [18,   320] loss: 0.509
# [18,   340] loss: 0.539
# [18,   360] loss: 0.513
# [19,    20] loss: 0.452
# [19,    40] loss: 0.438
# [19,    60] loss: 0.545
# [19,    80] loss: 0.443
# [19,   100] loss: 0.796
# [19,   120] loss: 0.411
# [19,   140] loss: 0.376
# [19,   160] loss: 0.415
# [19,   180] loss: 0.640
# [19,   200] loss: 0.362
# [19,   220] loss: 0.656
# [19,   240] loss: 0.550
# [19,   260] loss: 0.436
# [19,   280] loss: 0.509
# [19,   300] loss: 0.433
# [19,   320] loss: 0.390
# [19,   340] loss: 0.473
# [19,   360] loss: 0.330
# [20,    20] loss: 0.550
# [20,    40] loss: 0.368
# [20,    60] loss: 0.285
# [20,    80] loss: 0.413
# [20,   100] loss: 0.441
# [20,   120] loss: 0.341
# [20,   140] loss: 0.638
# [20,   160] loss: 0.800
# [20,   180] loss: 0.374
# [20,   200] loss: 0.407
# [20,   220] loss: 0.429
# [20,   240] loss: 0.330
# [20,   260] loss: 0.327
# [20,   280] loss: 0.511
# [20,   300] loss: 0.483
# [20,   320] loss: 0.556
# [20,   340] loss: 0.390
# [20,   360] loss: 0.406
# Finished Training

# %%
# Save our trained model
PATH = '/content/drive/MyDrive/HW3/HW3_model.pth'
torch.save(net.state_dict(), PATH)

# %%
model_test = ConvNet()
model_test.load_state_dict(torch.load(PATH))
model_test.eval()
# Out:
# ConvNet(
#   (conv1): Conv2d(3, 18, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(18, 18, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=8712, out_features=100, bias=True)
#   (fc2): Linear(in_features=100, out_features=50, bias=True)
#   (fc3): Linear(in_features=50, out_features=6, bias=True)
# )

# %%
testBatch = next(iter(test_data_loader))
images, labels = testBatch
outputs = model_test(images)
_, predicted = torch.max(outputs, 1)
print(predicted)
print('Predicted: ', ' '.join(f'{train_data.classes[predicted[j]]:5s}'
                              for j in range(4)))
# Out:
# tensor([3, 4, 5, 2])
# Predicted:  pitted_surface rolled-in_scale scratches patches

# %%
correct = 0
total = 0
res = []
# since we're not training, we don't need to calculate the gradients for our outputs
with torch.no_grad():
    for i in range(360):
        tpath = os.path.join(test_dir+'/',str(i)+'.jpg')
        fopen = Image.open(tpath)
        image = TRANSFORM_IMG(fopen)
        # calculate outputs by running images through the network
        # images, labels = data
        image = image.unsqueeze(0)
        outputs = model_test(image)
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)
        # you can modified the following code to show accuracy if you have split some validation set 
        # total += labels.size(0)
        # correct += (predicted == labels).sum().item()
        # print('Predicted: ', ' '.join(f'{train_data.classes[predicted[j]]:5s}'
        #                        for j in range(len(predicted))))
        for j in range(len(predicted)):
          res.append(str(train_data.classes[predicted[j]]))
print('Predict finished')
# print(f'Accuracy of the network on the {total} test images: {100 * correct // total} %')
# Out:
# Predict finished

# %%
df_ans = pd.DataFrame(res, columns=['Category'])
df_ans.to_csv('/content/drive/MyDrive/HW3/mySubmission.csv', index_label='Id')

# %% [markdown]
# ### Some tips for getting better result
# - image size (pick the best suitable size to input)
# - different CNN architecture
# - data augmentation
# - reasonable hyperparameter tuning strategy
